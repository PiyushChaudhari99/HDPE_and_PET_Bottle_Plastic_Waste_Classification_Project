# %%
import os

# %%
# %pwd
# Out:
# 'e:\\Data_Science_Projects\\CNN_Project\\HDPE_and_PET_Bottle_Plastic_Waste_classification_Project\\research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'e:\\Data_Science_Projects\\CNN_Project\\HDPE_and_PET_Bottle_Plastic_Waste_classification_Project'

# %%
from dataclasses import dataclass
from pathlib import Path

# %%
@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnImageClassifier.constants import *
from cnnImageClassifier.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
            self,
            config_filepath=CONFIG_FILE_PATH,
            params_filepath =PARAMS_FILE_PATH ):
        
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])
        
    

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL = config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnImageClassifier import logger
from cnnImageClassifier.utils.common import get_size

# %%
class DataIngestion():
    def __init__(self,config : DataIngestionConfig):
        self.config = config

    
    def download_file(self) -> str:
        ''' 
        Fetch data from the given URL
        '''
        try:
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion",exist_ok= True)
            logger.info(f"Downloading dataset from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = "https://drive.google.com/uc?/export=download&id="
            gdown.download(prefix+file_id,zip_download_dir)
            logger.info(f"Downloaded the data from {dataset_url} to file {zip_download_dir}")

        except Exception as e:
            raise e
        


    def extract_zip_file(self):
        '''
        zip_file_path :str
        Extracts the zip file downloaded form the url in to data directory
        function returns none
        '''

        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path,exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file,'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config  = ConfigurationManager()
    data_ingestion_config =config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2024-05-30 21:39:37,271: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-05-30 21:39:37,275: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-05-30 21:39:37,276: INFO: common: created directory at: artifacts]
# [2024-05-30 21:39:37,279: INFO: common: created directory at: artifacts/data_ingestion]
# [2024-05-30 21:39:37,281: INFO: 1334294821: Downloading dataset from https://drive.google.com/file/d/1tmLo5gb1PooR21OWqOuK8mxEWjIdO3GB/view?usp=sharing into file artifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1tmLo5gb1PooR21OWqOuK8mxEWjIdO3GB
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1tmLo5gb1PooR21OWqOuK8mxEWjIdO3GB&confirm=t&uuid=b8482cbc-100c-44bc-859a-5e5aa87b6bd8
# To: e:\Data_Science_Projects\CNN_Project\HDPE_and_PET_Bottle_Plastic_Waste_classification_Project\artifacts\data_ingestion\data.zip
# 100%|██████████| 133M/133M [00:42<00:00, 3.14MB/s]
# [2024-05-30 21:40:22,117: INFO: 1334294821: Downloaded the data from https://drive.google.com/file/d/1tmLo5gb1PooR21OWqOuK8mxEWjIdO3GB/view?usp=sharing to file artifacts/data_ingestion/data.zip]
